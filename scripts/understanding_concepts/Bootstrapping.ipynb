# %%
from scipy import stats
import numpy as np
import analysis_utilities as au
import matplotlib.pyplot as plt

# %%
condition1 = np.random.random(20)
condition2 = np.random.random(20)
original_mean_diff = abs(np.mean(condition1) - np.mean(condition2))
original_mean_diff
# Out:
# 0.09909042836076742

# %%
pval,dist = au.bootstrap(condition1, condition2,M=1e6,paired = True, return_distribution=True,alternative='less')
pval
# Out:
# 0.882809

# %%
plt.hist(dist)
plt.axvline(original_mean_diff)
# plt.axvline(-original_mean_diff)
