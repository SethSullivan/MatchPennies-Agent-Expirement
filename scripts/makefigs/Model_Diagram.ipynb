# %%
import graphviz as gv

# %%
d = gv.Digraph(name='model',
               graph_attr={'rankdir':'LR'},
               node_attr={'shape':'rectangle','fontsize':'20', 'width':'4', 'height':'4', 'penwidth':'5'},
               edge_attr={})
d.node("inputs", label="Physiological Delays\nand Uncertainties")#, shape='rectangle', fontsize="20", height="5", width="6", penwidth="8")
d.node("estimator", label="Internal Estimator", color='red')
d.edge("inputs","estimator", rank='same')
d
